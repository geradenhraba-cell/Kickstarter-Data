# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import matplotlib.ticker as mtick

# %%
ttrpg_2013 = pd.read_csv('../data/2013andEarlierRPGGeekKickstarterProjects - Tracking List.csv')

# %%
ttrpg_2014 = pd.read_csv('../data/2014RPGGeekKickstarterProjects - Tracking List.csv')

# %%
ttrpg_2015 = pd.read_csv('../data/2015RPGGeekKickstarterProjects - Tracking List.csv')

# %%
ttrpg_2016 = pd.read_csv('../data/2016RPGGeekKickstarterProjects - Tracking List.csv')

# %%
ttrpg_2017 = pd.read_csv('../data/2017RPGGeekKickstarterProjects - Tracking List.csv')

# %%
ttrpg_2018 = pd.read_csv('../data/2018RPGGeekKickstarterProjects - Tracking List.csv')

# %%
ttrpg_2019 = pd.read_csv('../data/2019RPGGeekKickstarterProjects - Tracking List.csv')

# %%
ttrpg_2020 = pd.read_csv('../data/2020RPGGeekKickstarterProjects - Tracking List.csv')

# %%
ttrpg_2021 = pd.read_csv('../data/2021RPGGeekKickstarterProjects - Tracking List.csv')

# %%
ttrpg_2022 = pd.read_csv('../data/2022RPGGeekKickstarterProjects - Tracking List.csv')

# %%
ttrpg_2023 = pd.read_csv('../data/2023RPGGeekKickstarterProjects - Tracking List.csv')

# %%
ttrpg_2024 = pd.read_csv('../data/2024RPGGeekKickstarterProjects - Tracking List.csv')

# %%
ttrpg_2025 = pd.read_csv('../data/2025RPGGeekKickstarterProjects - Tracking List.csv')

# %%
backerkit = pd.read_csv('../data/BackerKitProjects - Tracking List.csv')

# %%
gamefound = pd.read_csv('../data/GamefoundProjects - Tracking List.csv')

# %%
gametable = pd.read_csv('../data/GameOnTabletopProjects - Tracking List.csv')

# %%
ttrpg_2013.head()
# Out:
#                                     Kickstarter Link RPGGeek Item ID  \
# 0  https://www.kickstarter.com/projects/608022189...             NaN
# 1  https://www.kickstarter.com/projects/attention...             NaN
# 2  https://www.kickstarter.com/projects/wordstudi...             NaN
# 3  http://www.kickstarter.com/projects/jeffdee/ca...     item1949347
# 4  https://www.kickstarter.com/projects/jasonlbla...             NaN
#
#    RPGGeek Item Link                                      KickTraq Link  \
# 0                NaN  https://www.kicktraq.com/projects/608022189/wo...
# 1                NaN  https://www.kicktraq.com/projects/attentionspa...
# 2                NaN  https://www.kicktraq.com/projects/wordstudio/a...
# 3                NaN  https://www.kicktraq.com/projects/jeffdee/cave...
# 4                NaN  https://www.kicktraq.com/projects/669629655/st...
#
#      Type                        Non-5E: For RPG RPG: related to  \
# ...

# %%
ttrpg_2013.rename(columns = {'Unnamed: 8' : 'funded_date'}, inplace=True)

# %%
ttrpg_2013.rename(columns = {'Unnamed: 20' : 'funded_goal'}, inplace=True)

# %%
ttrpg_2013.columns
# Out:
# Index(['Kickstarter Link', 'RPGGeek Item ID', 'RPGGeek Item Link',
#        'KickTraq Link', 'Type', 'Non-5E: For RPG', 'RPG: related to',
#        'Project Name', 'funded_date', 'Ended?', 'Currency', 'Funding Level',
#        'Exchange Rate', 'LevelUSD', 'Funded?', 'Cancelled?', 'Reached Goal?',
#        'ExtractedFunding', 'ExtractedProgress', 'ExtractedTrend',
#        'funded_goal', 'Last Updated', 'Start Date', 'Unnamed: 23',
#        'Unnamed: 24'],
#       dtype='object')

# %%
ttrpg_2014.rename(columns = {'Unnamed: 8' : 'funded_date'}, inplace=True)

# %%
ttrpg_2014.rename(columns = {'Unnamed: 20' : 'funded_goal'}, inplace=True)

# %%
ttrpg_2014.rename(columns = {'Unnamed: 23' : 'description'}, inplace=True)

# %%
ttrpg_2015.rename(columns = {'Unnamed: 8' : 'funded_date'}, inplace=True)

# %%
ttrpg_2015.rename(columns = {'Unnamed: 20' : 'funded_goal'}, inplace=True)

# %%
ttrpg_2015.rename(columns = {'Unnamed: 23' : 'description'}, inplace=True)

# %%
ttrpg_2016.rename(columns = {'Unnamed: 8' : 'funded_date'}, inplace=True)

# %%
ttrpg_2016.rename(columns = {'Unnamed: 20' : 'funded_goal'}, inplace=True)

# %%
ttrpg_2016.rename(columns = {'Unnamed: 23' : 'Description'}, inplace=True)

# %%
ttrpg_2017.rename(columns = {'Unnamed: 8' : 'funded_date'}, inplace=True)

# %%
ttrpg_2017.rename(columns = {'Unnamed: 20' : 'funded_goal'}, inplace=True)

# %%
ttrpg_2017.rename(columns = {'Unnamed: 23' : 'description'}, inplace=True)

# %%
ttrpg_2018.rename(columns = {'Unnamed: 8' : 'funded_date'}, inplace=True)

# %%
ttrpg_2018.rename(columns = {'Unnamed: 20' : 'funded_goal'}, inplace=True)

# %%
ttrpg_2018.rename(columns = {'Unnamed: 23' : 'description'}, inplace=True)

# %%
ttrpg_2019.rename(columns = {'Unnamed: 8' : 'funded_date'}, inplace=True)

# %%
ttrpg_2019.rename(columns = {'Unnamed: 20' : 'funded_goal'}, inplace=True)

# %%
ttrpg_2019.rename(columns = {'Unnamed: 23' : 'description'}, inplace=True)

# %%
ttrpg_2020.rename(columns = {'Unnamed: 8' : 'funded_date'}, inplace=True)

# %%
ttrpg_2020.rename(columns = {'Unnamed: 20' : 'funded_goal'}, inplace=True)

# %%
ttrpg_2020.rename(columns = {'Unnamed: 23' : 'description'}, inplace=True)

# %%
ttrpg_2021.rename(columns = {'Unnamed: 20' : 'funded_goal'}, inplace=True)

# %%
ttrpg_2021.rename(columns = {'Unnamed: 8' : 'funded_date'}, inplace=True)

# %%
ttrpg_2021.rename(columns = {'Unnamed: 23' : 'description'}, inplace=True)

# %%
ttrpg_2022.rename(columns = {'Unnamed: 8' : 'funded_date'}, inplace=True)

# %%
ttrpg_2023.rename(columns = {'Unnamed: 8' : 'funded_date'}, inplace=True)

# %%
ttrpg_2024.rename(columns = {'Unnamed: 8' : 'funded_date'}, inplace=True)

# %%
ttrpg_2025.rename(columns = {'Unnamed: 8' : 'funded_date'}, inplace=True)

# %%
ttrpg_2022.rename(columns = {'Unnamed: 20' : 'funded_goal'}, inplace=True)

# %%
ttrpg_2023.rename(columns = {'Unnamed: 20' : 'funded_goal'}, inplace=True)

# %%
ttrpg_2024.rename(columns = {'Unnamed: 20' : 'funded_goal'}, inplace=True)

# %%
ttrpg_2025.rename(columns = {'Unnamed: 20' : 'funded_goal'}, inplace=True)

# %%
ttrpg_2022.rename(columns = {'Unnamed: 23' : 'description'}, inplace=True)

# %%
ttrpg_2023.rename(columns = {'Unnamed: 23' : 'description'}, inplace=True)

# %%
ttrpg_2024.rename(columns = {'Unnamed: 23' : 'description'}, inplace=True)

# %%
ttrpg_2025.rename(columns = {'Unnamed: 23' : 'description'}, inplace=True)

# %%
ttrpg_2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 535 entries, 0 to 534
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Kickstarter Link   535 non-null    object
#  1   RPGGeek Item ID    528 non-null    object
#  2   RPGGeek Item Link  0 non-null      float64
#  3   KickTraq Link      535 non-null    object
#  4   Type               535 non-null    object
#  5   Non-5E: For RPG    269 non-null    object
#  6   RPG: related to    33 non-null     object
#  7   Project Name       535 non-null    object
#  8   funded_date        535 non-null    object
#  9   Ended?             535 non-null    object
#  10  Currency           535 non-null    object
#  11  Funding Level      535 non-null    object
#  12  Exchange Rate      535 non-null    float64
#  13  LevelUSD           535 non-null    object
#  14  Funded?            535 non-null    object
#  15  Cancelled?         535 non-null    object
# ...

# %%
dfs = {
    2013: ttrpg_2013,
    2014: ttrpg_2014,
    2015: ttrpg_2015,
    2016: ttrpg_2016,
    2017: ttrpg_2017,
    2018: ttrpg_2018,
    2019: ttrpg_2019,
    2020: ttrpg_2020,
    2021: ttrpg_2021,
    2022: ttrpg_2022,
    2023: ttrpg_2023,
    2024: ttrpg_2024,
    2025: ttrpg_2025,}

ttrpg_all = pd.concat(
    [df.assign(year=year) for year, df in dfs.items()],
    ignore_index=True)

# %%
ttrpg_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12712 entries, 0 to 12711
# Data columns (total 55 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Kickstarter Link                 12711 non-null  object
#  1   RPGGeek Item ID                  2065 non-null   object
#  2   RPGGeek Item Link                51 non-null     object
#  3   KickTraq Link                    12710 non-null  object
#  4   Type                             12711 non-null  object
#  5   Non-5E: For RPG                  4127 non-null   object
#  6   RPG: related to                  908 non-null    object
#  7   Project Name                     11388 non-null  object
#  8   funded_date                      535 non-null    object
#  9   Ended?                           12712 non-null  object
#  10  Currency                         12712 non-null  object
#  11  Funding Level                    12712 non-null  object
# ...

# %%
cols = ["Description", "description", "Blurb"]

ttrpg_all[cols] = ttrpg_all[cols].replace(r"^\s*$", pd.NA, regex=True)

ttrpg_all["combined_description"] = (
    ttrpg_all[cols]
    .bfill(axis=1)
    .iloc[:, 0])
# Out:
# C:\Users\Geraden\AppData\Local\Temp\ipykernel_16008\3092415278.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .bfill(axis=1)

# %%
ttrpg_all = ttrpg_all.drop(columns=["Description", "description", "Blurb"])

# %%
ttrpg_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12712 entries, 0 to 12711
# Data columns (total 53 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Kickstarter Link                 12711 non-null  object
#  1   RPGGeek Item ID                  2065 non-null   object
#  2   RPGGeek Item Link                51 non-null     object
#  3   KickTraq Link                    12710 non-null  object
#  4   Type                             12711 non-null  object
#  5   Non-5E: For RPG                  4127 non-null   object
#  6   RPG: related to                  908 non-null    object
#  7   Project Name                     11388 non-null  object
#  8   funded_date                      535 non-null    object
#  9   Ended?                           12712 non-null  object
#  10  Currency                         12712 non-null  object
#  11  Funding Level                    12712 non-null  object
# ...

# %%
ttrpg_all = ttrpg_all.loc[:, ~ttrpg_all.columns.str.startswith("Unnamed")]

# %%
cols_to_drop = [
    "RPGGeek List Page",
    "Linked RPGs",
    "LevelUSD.1",
    "OSR Original",
    "OSR Scene",
    "Image Link",
    "Geeklist Code",
    'TrueLevelUSD ("Not Funded" = 0)',
    "FundedDate",
    "Funded Value",
    "OSR-Core",
    "OSR-Adjacent",
    "OSR Core",
    "OSR Adjacent",
    "RPGGeek List Item",
    "Funding Goal",
]

ttrpg_all = (
    ttrpg_all
    .loc[:, ~ttrpg_all.columns.str.startswith("Unnamed")]
    .drop(columns=cols_to_drop, errors="ignore")
)

# %%
ttrpg_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12712 entries, 0 to 12711
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Kickstarter Link      12711 non-null  object
#  1   RPGGeek Item ID       2065 non-null   object
#  2   RPGGeek Item Link     51 non-null     object
#  3   KickTraq Link         12710 non-null  object
#  4   Type                  12711 non-null  object
#  5   Non-5E: For RPG       4127 non-null   object
#  6   RPG: related to       908 non-null    object
#  7   Project Name          11388 non-null  object
#  8   funded_date           535 non-null    object
#  9   Ended?                12712 non-null  object
#  10  Currency              12712 non-null  object
#  11  Funding Level         12712 non-null  object
#  12  Exchange Rate         12565 non-null  float64
#  13  LevelUSD              12712 non-null  object
#  14  Funded?               12712 non-null  object
# ...

# %%
ttrpg_all.head(10)
# Out:
#                                     Kickstarter Link RPGGeek Item ID  \
# 0  https://www.kickstarter.com/projects/608022189...             NaN
# 1  https://www.kickstarter.com/projects/attention...             NaN
# 2  https://www.kickstarter.com/projects/wordstudi...             NaN
# 3  http://www.kickstarter.com/projects/jeffdee/ca...     item1949347
# 4  https://www.kickstarter.com/projects/jasonlbla...             NaN
# 5  http://www.kickstarter.com/projects/135802053/...     item1945550
# 6  http://www.kickstarter.com/projects/1806106772...     item1944501
# 7  https://www.kickstarter.com/projects/131618942...             NaN
# 8  http://www.kickstarter.com/projects/462624115/...     item1949345
# 9  https://www.kickstarter.com/projects/180136007...             NaN
#
#   RPGGeek Item Link                                      KickTraq Link  \
# 0               NaN  https://www.kicktraq.com/projects/608022189/wo...
# ...

# %%
ttrpg_all = ttrpg_all.drop(ttrpg_all.columns[[0, 1, 2, 3, 24]], axis=1)

# %%
date_cols = ['funded_date', 'Ended?', 'Last Updated', 'Start Date']

for col in date_cols:
    ttrpg_all[col] = pd.to_datetime(ttrpg_all[col], errors='coerce')
# Out:
# C:\Users\Geraden\AppData\Local\Temp\ipykernel_16008\123232015.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ttrpg_all[col] = pd.to_datetime(ttrpg_all[col], errors='coerce')

# %%
num_cols = ['Funding Level', 'LevelUSD', 'funded_goal']

for col in num_cols:
    ttrpg_all[col] = (
        ttrpg_all[col]
        .astype(str)
        .str.replace(r'[^\d.-]', '', regex=True)
        .replace('', pd.NA))
    ttrpg_all[col] = pd.to_numeric(ttrpg_all[col], errors='coerce')

# %%
ttrpg_all['ExtractedFunding'] = (
    ttrpg_all['ExtractedFunding']
    .astype(str)
    .str.replace(r'[^\d.-]', '', regex=True)
    .astype(float))

# %%
ttrpg_all.columns
# Out:
# Index(['Type', 'Non-5E: For RPG', 'RPG: related to', 'Project Name',
#        'funded_date', 'Ended?', 'Currency', 'Funding Level', 'Exchange Rate',
#        'LevelUSD', 'Funded?', 'Cancelled?', 'Reached Goal?',
#        'ExtractedFunding', 'ExtractedProgress', 'ExtractedTrend',
#        'funded_goal', 'Last Updated', 'Start Date', 'year',
#        'combined_description'],
#       dtype='object')

# %%
ttrpg_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12712 entries, 0 to 12711
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Type                  12711 non-null  object
#  1   Non-5E: For RPG       4127 non-null   object
#  2   RPG: related to       908 non-null    object
#  3   Project Name          11388 non-null  object
#  4   funded_date           484 non-null    datetime64[ns]
#  5   Ended?                0 non-null      datetime64[ns]
#  6   Currency              12712 non-null  object
#  7   Funding Level         12712 non-null  float64
#  8   Exchange Rate         12565 non-null  float64
#  9   LevelUSD              10661 non-null  float64
#  10  Funded?               12712 non-null  object
#  11  Cancelled?            12712 non-null  object
#  12  Reached Goal?         12712 non-null  object
#  13  ExtractedFunding      12712 non-null  float64
# ...

# %%
ttrpg_all
# Out:
#          Type                        Non-5E: For RPG RPG: related to  \
# 0      non-5E                                    D&D             NaN
# 1      non-5E  https://rpggeek.com/rpg/16823/carmine             NaN
# 2         RPG                                    NaN             NaN
# 3         RPG                                    NaN             NaN
# 4         RPG                                    NaN             NaN
# ...       ...                                    ...             ...
# 12707      5E                                    NaN             NaN
# 12708      5E                                    NaN             NaN
# 12709     RPG                                    NaN             NaN
# 12710     RPG                                    NaN             NaN
# 12711      5E                                    NaN             NaN
#
#                                             Project Name funded_date Ended?  \
# ...

# %%
cols = ['Funded?', 'Cancelled?', 'Reached Goal?']

mapping = {
    'TRUE': 1.0, 'FALSE': 0.0,
    'YES': 1.0, 'NO': 0.0,
    'Y': 1.0, 'N': 0.0,
    True: 1.0, False: 0.0
}

for c in cols:
    ttrpg_all[c] = (
        ttrpg_all[c]
            .astype(str)
            .str.strip()
            .str.upper()
            .replace(mapping)
            .astype(float)
    )

ttrpg_all
# Out:
# C:\Users\Geraden\AppData\Local\Temp\ipykernel_16008\495972522.py:16: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .replace(mapping)
# C:\Users\Geraden\AppData\Local\Temp\ipykernel_16008\495972522.py:16: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .replace(mapping)
# ...

# %% [markdown]
# 1 = true, 0 = false

# %%
success_col = 'Reached Goal?'

total_projects = ttrpg_all[success_col].notna().sum()
successful_projects = (ttrpg_all[success_col] == 1.0).sum()

success_rate = successful_projects / total_projects * 100

total_projects, successful_projects, success_rate
# Out:
# (12712, 10742, 84.50283196979233)

# %%
yearly_success = (
    ttrpg_all
        .dropna(subset=[success_col])
        .groupby('year')[success_col]
        .mean() * 100
)

yearly_success
# Out:
# year
# 2013    76.261682
# 2014    71.472393
# 2015    73.130194
# 2016    78.227848
# 2017    84.682713
# 2018    82.198953
# 2019    81.625000
# 2020    83.867833
# 2021    88.691323
# 2022    86.308623
# 2023    85.174746
# 2024    86.910440
# 2025    87.439090
# Name: Reached Goal?, dtype: float64

# %%
median_yearly_success = yearly_success.median()
median_yearly_success
# Out:
# 83.86783284742468

# %%
ttrpg_all['is_5e'] = ttrpg_all['Non-5E: For RPG'].isna()

funded_by_category = (
    ttrpg_all
        .groupby('is_5e')['LevelUSD']
        .sum())

funded_by_category.index = funded_by_category.index.map({True: '5E', False: 'Non-5E'})
print(funded_by_category)
# Out:
# is_5e
# Non-5E    1.059045e+08
# 5E        2.996062e+08
# Name: LevelUSD, dtype: float64

# %%
currency_counts = ttrpg_all['Currency'].value_counts()

total_projects = len(ttrpg_all)

usd_pct = (currency_counts.get('USD', 0) / total_projects) * 100
other_pct = 100 - usd_pct

print(f"USD projects: {usd_pct:.2f}%")
print(f"Other currencies: {other_pct:.2f}%")
# Out:
# USD projects: 63.61%
# Other currencies: 36.39%

# %%
funded_by_currency = ttrpg_all.groupby('Currency')['LevelUSD'].sum()
print(funded_by_currency)
# Out:
# Currency
# AUD    3.116385e+06
# CAD    8.552968e+06
# CHF    1.200435e+04
# DKK    2.311991e+05
# EUR    3.883834e+07
# GBP    4.458796e+07
# HKD    2.478025e+04
# JPY    5.244805e+05
# MXN    2.826889e+05
# NOK    9.880260e+04
# NZD    1.919660e+05
# SEK    2.231984e+07
# USD    2.867293e+08
# Name: LevelUSD, dtype: float64

# %%
funded_by_year = ttrpg_all.groupby('year')['LevelUSD'].sum()
print(funded_by_year)
# Out:
# year
# 2013    1.332068e+07
# 2014    6.828597e+06
# 2015    8.042221e+06
# 2016    1.208105e+07
# 2017    1.050994e+07
# 2018    1.764442e+07
# 2019    2.396986e+07
# 2020    2.816094e+07
# 2021    7.205201e+07
# 2022    4.952292e+07
# 2023    5.703216e+07
# 2024    6.367359e+07
# 2025    4.267232e+07
# Name: LevelUSD, dtype: float64

# %%
funded_by_year_currency = ttrpg_all.groupby(['year', 'Currency'])['LevelUSD'].sum()
print(funded_by_year_currency)
# Out:
# year  Currency
# 2013  EUR           506108.29
#       GBP           720369.65
#       USD         12094204.00
# 2014  AUD             4369.25
#       CAD             6388.86
#                      ...
# 2025  JPY            68663.19
#       MXN            22397.00
#       NZD             6596.64
#       SEK          4193115.22
#       USD         24828351.00
# Name: LevelUSD, Length: 120, dtype: float64

# %%
funded_by_year_currency_pivot = funded_by_year_currency.unstack(fill_value=0)
print(funded_by_year_currency_pivot)
# Out:
# Currency        AUD         CAD       CHF       DKK           EUR         GBP  \
# year
# 2013           0.00        0.00      0.00      0.00  5.061083e+05   720369.65
# 2014        4369.25     6388.86      0.00      0.00  4.547075e+05  1063010.91
# 2015       55858.03    77136.12      0.00      0.00  4.631191e+05   947271.06
# 2016       82316.90   320424.62      0.00      0.00  5.699648e+05   900569.36
# 2017      119665.88   181892.98      0.00  13596.06  4.744166e+05  1309404.62
# 2018      152189.65   362353.48      0.00  68066.81  3.004772e+06  1863174.17
# 2019      488375.58   804599.56      0.00   2526.52  1.178231e+06  1608814.17
# 2020      112395.20   755700.92      0.00  44018.41  2.204445e+06  3632307.44
# 2021      617020.35  2180545.43      0.00  23666.63  4.640092e+06  7730945.68
# 2022      528271.22   516844.77      0.00  38663.33  5.414260e+06  6305269.56
# 2023      348157.01  1330816.86      0.00   5250.91  6.444256e+06  5058869.27
# ...

# %%
ttrpg_all['Type'].unique()
# Out:
# array(['non-5E', 'RPG', '5E', nan,
#        'https://rpggeek.com/rpg/1297/old-school-reference-and-index-compilation-osric'],
#       dtype=object)

# %%
ttrpg_all['Type'] = ttrpg_all['Type'].replace(
    'https://rpggeek.com/rpg/1297/old-school-reference-and-index-compilation-osric', 
    pd.NA)

# %%
ttrpg_all['type_filled'] = ttrpg_all['Type'].fillna('Unknown')

ttrpg_known = ttrpg_all[ttrpg_all['type_filled'] != 'Unknown']

# %%
type_palette = [
    "#001524",  
    "#FF7D00",  
    "#78290F",  
]

# %%
ttrpg_all['type_filled'] = ttrpg_all['Type'].fillna('Unknown')

funding_by_year_type = ttrpg_all.groupby(['year', 'type_filled'])['LevelUSD'].sum()

funding_by_year_type_pivot = funding_by_year_type.unstack(fill_value=0)

funding_by_year_type_pivot = funding_by_year_type_pivot.applymap(lambda x: f"${x:,.0f}")

print(funding_by_year_type_pivot)
# Out:
# type_filled           5E          RPG Unknown       non-5E
# year
# 2013                  $0   $7,065,721      $0   $6,254,961
# 2014             $67,081   $2,744,361      $0   $4,017,155
# 2015            $599,996   $3,463,828      $0   $3,978,398
# 2016          $1,046,781   $6,706,414      $0   $4,327,854
# 2017          $2,087,781   $3,885,229      $0   $4,536,930
# 2018          $5,764,031   $4,821,304      $0   $7,059,087
# 2019          $7,858,644   $9,463,216      $0   $6,647,996
# 2020         $13,394,373   $8,125,959      $0   $6,640,605
# 2021         $32,423,114  $21,145,319      $0  $18,483,577
# 2022         $22,898,380  $16,250,446      $0  $10,374,094
# 2023         $28,922,895  $14,985,084    $959  $13,123,226
# 2024         $18,277,176  $32,647,449      $0  $12,748,969
# 2025         $16,445,719  $10,295,316  $8,521  $15,922,767
# ...

# %%
plt.figure(figsize=(12,6))
sns.barplot(
    data=ttrpg_known,
    x='year',
    y='LevelUSD',
    hue='type_filled',
    estimator=sum,
    ci=None,
    palette=type_palette
)

plt.title('TTRPG Funding per Year by Type')
plt.ylabel('Total Funding (USD)')
plt.xlabel('Year')

formatter = FuncFormatter(lambda x, _: f"${x:,.0f}")
plt.gca().yaxis.set_major_formatter(formatter)

plt.legend(title='Type')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Geraden\AppData\Local\Temp\ipykernel_16008\1079364979.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(

# %%
labels = ['USD', 'Other currencies']
sizes = [usd_pct, other_pct]
colors = ['#1f77b4', '#ff7f0e'] 
explode = (0.1, 0)  

plt.figure(figsize=(6,6))
plt.pie(
    sizes, 
    labels=labels, 
    autopct='%1.1f%%',  
    startangle=90,
    colors=colors,
    explode=explode,
    shadow=True)
plt.title('Percentage of Projects in USD vs Other Currencies')
plt.show()

# %%
yearly_success_df = yearly_success.reset_index()
yearly_success_df.columns = ['year', 'success_pct']

plt.figure(figsize=(12,6))
sns.lineplot(data=yearly_success_df, x='year', y='success_pct', marker='o')
plt.title('Yearly TTRPG Success Rate')
plt.ylabel('Success Rate (%)')
plt.xlabel('Year')
plt.ylim(0, 100)  
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
funding_long = funded_by_year_currency_pivot.reset_index().melt(
    id_vars='year',
    var_name='Currency',
    value_name='LevelUSD'
)

funding_long_non_usd = funding_long[
    (funding_long['Currency'] != 'USD') &
    (funding_long['LevelUSD'] > 0)
]

# %%
cb_palette_13 = [
    "#4477AA", 
    "#66CCEE",  
    "#228833",  
    "#CCBB44",  
    "#EE6677",  
    "#AA3377",  
    "#BBBBBB",  
    "#000000",  
    "#332288", 
    "#88CCEE",  
    "#44AA99",  
    "#999933",  
    "#DDCC77",  
]

# %%
plt.figure(figsize=(12,6))
sns.barplot(
    data=funding_long_non_usd,
    x='year',
    y='LevelUSD',
    hue='Currency',
    estimator=sum,
    ci=None,
    palette=cb_palette_13
)

plt.title('TTRPG Funding per Year by Non-USD Currencies')
plt.ylabel('Total Funding (USD)')
plt.xlabel('Year')

formatter = FuncFormatter(lambda x, _: f"${x:,.0f}")
plt.gca().yaxis.set_major_formatter(formatter)

plt.xticks(rotation=45)
plt.legend(title='Currency')
plt.show()
# Out:
# C:\Users\Geraden\AppData\Local\Temp\ipykernel_16008\2424602177.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(
# C:\Users\Geraden\AppData\Local\Temp\ipykernel_16008\2424602177.py:2: UserWarning: The palette list has more values (13) than needed (12), which may not be intended.
#   sns.barplot(

# %%
funding_long = funded_by_year_currency_pivot.reset_index().melt(
    id_vars='year',
    var_name='Currency',
    value_name='LevelUSD'
)

funding_long = funding_long[funding_long['LevelUSD'] > 0]

currency_order = sorted(funding_long['Currency'].unique())
palette_map = dict(zip(currency_order, cb_palette_13))

plt.figure(figsize=(12,6))
sns.lineplot(
    data=funding_long,
    x='year',
    y='LevelUSD',
    hue='Currency',
    hue_order=currency_order,
    palette=palette_map,
    marker='o'
)

plt.title('TTRPG Funding per Year by Currency')
plt.ylabel('Total Funding (USD)')
plt.xlabel('Year')

formatter = FuncFormatter(lambda x, _: f"${x:,.0f}")
plt.gca().yaxis.set_major_formatter(formatter)

plt.xticks(rotation=45)
plt.legend(title='Currency', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
backerkit.head()
# Out:
#                                       BackerKit Link  \
# 0  https://www.backerkit.com/c/projects/roll-and-...
# 1  https://www.backerkit.com/c/projects/exalted-f...
# 2  https://www.backerkit.com/c/projects/monte-coo...
# 3  https://www.backerkit.com/c/projects/connor-al...
# 4  https://www.backerkit.com/c/projects/snowbrigh...
#
#                                    RPGGeek List Item    Type  \
# 0  https://rpggeek.com/geeklist/349562/backerkit-...      5E
# 1  https://rpggeek.com/geeklist/349562/backerkit-...     RPG
# 2  https://rpggeek.com/geeklist/349562/backerkit-...  non-5E
# 3  https://rpggeek.com/geeklist/349562/backerkit-...  non-5E
# 4  https://rpggeek.com/geeklist/349562/backerkit-...     RPG
#
#                                  Non-5E: For RPG RPG: related to  \
# 0                                            NaN             NaN
# 1                                            NaN             NaN
# 2  https://rpggeek.com/rpg/356/generic-universal             NaN
# ...

# %%
gamefound.head()
# Out:
#                                       Gamefound Link  \
# 0  https://gamefound.com/en/projects/cbatarlis/ta...
# 1  https://gamefound.com/en/projects/seven-sagas/...
# 2  https://gamefound.com/en/projects/triple-ace-g...
# 3  https://gamefound.com/en/projects/studio-agate...
# 4  https://gamefound.com/en/projects/shadowlands/...
#
#                                    RPGGeek List Item    Type  \
# 0  https://rpggeek.com/geeklist/360108/gamefound-...     RPG
# 1  https://rpggeek.com/geeklist/360108/gamefound-...     RPG
# 2  https://rpggeek.com/geeklist/360108/gamefound-...  non-5E
# 3  https://rpggeek.com/geeklist/360108/gamefound-...     RPG
# 4  https://rpggeek.com/geeklist/360108/gamefound-...     RPG
#
#                                      Non-5E: For RPG  \
# 0                                                NaN
# 1                                                NaN
# 2  https://rpggeek.com/rpg/11973/leagues-of-adven...
# 3                                                NaN
# ...

# %%
gametable.head()
# Out:
#                                  GameOnTabletop Link  \
# 0  https://www.gameontabletop.com/cf3291/la-foret...
# 1  https://www.gameontabletop.com/cf3971/les-miro...
# 2  https://www.gameontabletop.com/cf3991/chroniqu...
# 3  https://www.gameontabletop.com/cf4441/dream-as...
# 4  https://www.gameontabletop.com/cf2021/shiver-l...
#
#                                    RPGGeek List Item    Type  \
# 0  https://rpggeek.com/geeklist/360124/gameontabl...     RPG
# 1  https://rpggeek.com/geeklist/360124/gameontabl...  non-5E
# 2  https://rpggeek.com/geeklist/360124/gameontabl...  non-5E
# 3  https://rpggeek.com/geeklist/360124/gameontabl...  non-5E
# 4  https://rpggeek.com/geeklist/360124/gameontabl...  non-5E
#
#                                      Non-5E: For RPG RPG: related to  \
# 0                                                NaN             NaN
# 1        https://rpggeek.com/rpg/4284/reve-de-dragon             NaN
# ...

# %%
gamefound.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gamefound Link     103 non-null    object
#  1   RPGGeek List Item  103 non-null    object
#  2   Type               103 non-null    object
#  3   Non-5E: For RPG    33 non-null     object
#  4   RPG: related to    8 non-null      object
#  5   Project Name       103 non-null    object
#  6   Ended Date         103 non-null    object
#  7   Funding Level      103 non-null    object
#  8   Project Status     103 non-null    object
#  9   Currency           103 non-null    object
#  10  Funding Level.1    103 non-null    object
#  11  Exchange Rate      103 non-null    float64
#  12  FundingLevelUSD    103 non-null    object
#  13  OSR Original       1 non-null      float64
#  14  OSR Scene          0 non-null      float64
# dtypes: float64(3), object(12)
# ...

# %%
gamefound = gamefound.drop(gamefound.columns[[0, 1, 3, 13, 14,4]], axis=1)

# %%
gamefound.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             103 non-null    object
#  1   Project Name     103 non-null    object
#  2   Ended Date       103 non-null    object
#  3   Funding Level    103 non-null    object
#  4   Project Status   103 non-null    object
#  5   Currency         103 non-null    object
#  6   Funding Level.1  103 non-null    object
#  7   Exchange Rate    103 non-null    float64
#  8   FundingLevelUSD  103 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 7.4+ KB

# %%
print(gamefound['Ended Date'].head())
# Out:
# 0          2023-03-14
# 1        March 1 2024
# 2     November 1 2023
# 3    February 13 2024
# 4    February 13 2024
# Name: Ended Date, dtype: object

# %%
from dateutil import parser

gamefound['Ended Date'] = gamefound['Ended Date'].apply(lambda x: parser.parse(x).strftime('%Y-%m-%d'))

# %%
gamefound.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             103 non-null    object
#  1   Project Name     103 non-null    object
#  2   Ended Date       103 non-null    object
#  3   Funding Level    103 non-null    object
#  4   Project Status   103 non-null    object
#  5   Currency         103 non-null    object
#  6   Funding Level.1  103 non-null    object
#  7   Exchange Rate    103 non-null    float64
#  8   FundingLevelUSD  103 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 7.4+ KB

# %%
gamefound['Ended Date'] = pd.to_datetime(
    gamefound['Ended Date'],  
    errors='coerce',           
    infer_datetime_format=True 
)
gamefound.head()
# Out:
# C:\Users\Geraden\AppData\Local\Temp\ipykernel_16008\801053973.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   gamefound['Ended Date'] = pd.to_datetime(
#      Type                                       Project Name Ended Date  \
# 0     RPG  Talislanta the Epic Tabletop Roleplaying Game ... 2023-03-14
# 1     RPG                             Dawnfall: Aitechnocene 2024-03-01
# 2  non-5E                       Mordavia: Revised & Expanded 2023-11-01
# 3     RPG         Tainted Grail TTRPG: Song of a Dying World 2024-02-13
# 4     RPG             The Winter King - The Roleplaying Game 2024-02-13
#
#   Funding Level Project Status Currency Funding Level.1  Exchange Rate  \
# 0   $158,273.50  Project Ended      USD      158,273.50         1.0000
# ...

# %%
print(gamefound['Funding Level'])
# Out:
# 0      $158,273.50
# 1        €2,625.00
# 2        £2,267.25
# 3      €315,602.31
# 4      €112,853.95
#           ...
# 98       £4,963.97
# 99              $0
# 100     €14,683.54
# 101      €3,797.25
# 102          €0.00
# Name: Funding Level, Length: 103, dtype: object

# %%
gamefound.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             103 non-null    object
#  1   Project Name     103 non-null    object
#  2   Ended Date       103 non-null    datetime64[ns]
#  3   Funding Level    103 non-null    object
#  4   Project Status   103 non-null    object
#  5   Currency         103 non-null    object
#  6   Funding Level.1  103 non-null    object
#  7   Exchange Rate    103 non-null    float64
#  8   FundingLevelUSD  103 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(7)
# memory usage: 7.4+ KB

# %%
currency_cols = ['Funding Level', 'Funding Level.1', 'FundingLevelUSD']

def to_numeric_currency(x):
    if pd.isnull(x):
        return float('nan')
   
    cleaned = ''.join(c for c in str(x) if c.isdigit() or c in ['.', '-'])
    try:
        return float(cleaned)
    except:
        return float('nan')


for col in currency_cols:
    gamefound[col] = gamefound[col].apply(to_numeric_currency)

# %%
gamefound.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             103 non-null    object
#  1   Project Name     103 non-null    object
#  2   Ended Date       103 non-null    datetime64[ns]
#  3   Funding Level    103 non-null    float64
#  4   Project Status   103 non-null    object
#  5   Currency         103 non-null    object
#  6   Funding Level.1  103 non-null    float64
#  7   Exchange Rate    103 non-null    float64
#  8   FundingLevelUSD  103 non-null    float64
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 7.4+ KB

# %%
unique_statuses = gamefound['Project Status'].unique()
print(unique_statuses)
# Out:
# ['Project Ended' 'Not Funded' 'Cancelled']

# %%
status_counts = gamefound['Project Status'].value_counts()
percentages = status_counts / status_counts.sum() * 100

legend_labels = [
    f"{status}: {pct:.1f}%"
    for status, pct in zip(status_counts.index, percentages)
]

plt.figure(figsize=(8, 6))
plt.pie(
    status_counts,
    labels=None,         
    startangle=90,
    wedgeprops={'edgecolor': 'white'}
)

plt.legend(
    legend_labels,
    title="Project Status",
    loc="center left",
    bbox_to_anchor=(1, 0.5)
)

plt.title('Gamefound Project Status Distribution')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
kick_unique_statuses = ttrpg_all['ExtractedTrend'].unique()
print(kick_unique_statuses)
# Out:
# ['Cancelled' 'Ended' 'Ongoing']

# %%
status_counts = ttrpg_all['ExtractedTrend'].value_counts()

explode = [0.1 if status in ['Cancelled', 'Ongoing'] else 0 for status in status_counts.index]

plt.figure(figsize=(6,6))
plt.pie(status_counts, labels=status_counts.index, startangle=200,
        explode=explode, wedgeprops={'edgecolor':'white'})

total = status_counts.sum()
percentages = [f'{(count/total*100):.1f}%' for count in status_counts]
plt.legend(labels=[f'{label} - {pct}' for label, pct in zip(status_counts.index, percentages)],
           title="Project Status",
           loc="center left",
           bbox_to_anchor=(1, -0.1, 0.5, 1)) 

plt.title('Kickstarter Project Status Distribution')
plt.show()

# %%
currency_status = pd.crosstab(gamefound['Currency'], gamefound['Project Status'])
print(currency_status)
# Out:
# Project Status  Cancelled  Not Funded  Project Ended
# Currency
# AUD                     0           1              5
# CAD                     0           0              1
# EUR                     0           3             35
# GBP                     0           0             10
# PLN                     0           0              8
# USD                     2           4             34

# %%
currency_status.plot(kind='bar', stacked=True, figsize=(12,6))
plt.ylabel('Number of Projects')
plt.xlabel('Currency')
plt.title('Gamefound Project Status Distribution by Currency')
plt.xticks(rotation=45)
plt.legend(title='Project Status')
plt.tight_layout()
plt.show()

# %%
gamefound
# Out:
#        Type                                       Project Name Ended Date  \
# 0       RPG  Talislanta the Epic Tabletop Roleplaying Game ... 2023-03-14
# 1       RPG                             Dawnfall: Aitechnocene 2024-03-01
# 2    non-5E                       Mordavia: Revised & Expanded 2023-11-01
# 3       RPG         Tainted Grail TTRPG: Song of a Dying World 2024-02-13
# 4       RPG             The Winter King - The Roleplaying Game 2024-02-13
# ..      ...                                                ...        ...
# 98      RPG                                           Moonwych 2025-11-11
# 99       5E  Duality of Life & Death: A D&D 5e Magic Item Deck 2025-11-14
# 100  non-5E                        Traveller: Campañas navales 2025-11-26
# 101     RPG                                        Picaria GDR 2025-11-30
# 102     RPG            The Hidden Keys - An Urban Horror TTRPG 2025-12-02
#
#      Funding Level Project Status Currency  Funding Level.1  Exchange Rate  \
# ...

# %%
backerkit = backerkit.drop(backerkit.columns[[0, 1, 3, 4, 22, 23, 24,12,11]], axis=1)

print(backerkit.columns)
# Out:
# Index(['Type', 'Project Name', 'Ended Date', 'Funding Level', 'Funding Goal',
#        'Project Status', 'Project Blurb', 'Currency', 'Funding Level.1',
#        'Exchange Rate', 'FundingLevelUSD', 'Goal Level', 'Reached Goal?',
#        'Progress', 'Success?', 'Real Funding USD'],
#       dtype='object')

# %%
backerkit
# Out:
#        Type                                   Project Name    Ended Date  \
# 0        5E    Monsters, Maps & Magic Items: Royal Edition  Jun 15, 2022
# 1       RPG                                    Land of Eem  Aug 12, 2022
# 2    non-5E                                      The Weird   Oct 8, 2022
# 3    non-5E       Coyote & Crow: Stories of the Free Lands  Oct 13, 2022
# 4       RPG                                            ink   Nov 1, 2022
# ..      ...                                            ...           ...
# 590  non-5E               Land of Eem - edición en español           NaN
# 591     RPG  Amboria: World Under Starlight - Last Chance!           NaN
# 592  non-5E                               Ultimate Toolbox           NaN
# 593  non-5E                  Unnatural Selections Volume 4           NaN
# 594  non-5E                      Draw Steel: Crack the Sun           NaN
#
#     Funding Level Funding Goal Project Status  \
# ...

# %%
backerkit['Ended Date'] = pd.to_datetime(
    backerkit['Ended Date'],
    errors='coerce')

# %%
backerkit['Ongoing'] = backerkit['Ended Date'].isna()

# %%
backerkit
# Out:
#        Type                                   Project Name Ended Date  \
# 0        5E    Monsters, Maps & Magic Items: Royal Edition 2022-06-15
# 1       RPG                                    Land of Eem 2022-08-12
# 2    non-5E                                      The Weird 2022-10-08
# 3    non-5E       Coyote & Crow: Stories of the Free Lands 2022-10-13
# 4       RPG                                            ink 2022-11-01
# ..      ...                                            ...        ...
# 590  non-5E               Land of Eem - edición en español        NaT
# 591     RPG  Amboria: World Under Starlight - Last Chance!        NaT
# 592  non-5E                               Ultimate Toolbox        NaT
# 593  non-5E                  Unnatural Selections Volume 4        NaT
# 594  non-5E                      Draw Steel: Crack the Sun        NaT
#
#     Funding Level Funding Goal Project Status  \
# 0          £3,601         £500  Project Ended
# ...

# %%
backerkit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595 entries, 0 to 594
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Type              595 non-null    object
#  1   Project Name      595 non-null    object
#  2   Ended Date        287 non-null    datetime64[ns]
#  3   Funding Level     595 non-null    object
#  4   Funding Goal      595 non-null    object
#  5   Project Status    582 non-null    object
#  6   Project Blurb     595 non-null    object
#  7   Currency          595 non-null    object
#  8   Funding Level.1   595 non-null    object
#  9   Exchange Rate     595 non-null    float64
#  10  FundingLevelUSD   595 non-null    object
#  11  Goal Level        595 non-null    float64
#  12  Reached Goal?     595 non-null    object
#  13  Progress          595 non-null    object
#  14  Success?          595 non-null    object
#  15  Real Funding USD  595 non-null    object
# ...

# %%
currency_cols = backerkit.columns[[3, 4, 8, 10, 11, 15]]

# %%
for col in currency_cols:
    backerkit[col] = (
        backerkit[col]
        .astype(str)
        .str.replace(r'[^\d\.-]', '', regex=True)  
        .replace('', pd.NA)                        
        .astype(float)
    )
backerkit
# Out:
#        Type                                   Project Name Ended Date  \
# 0        5E    Monsters, Maps & Magic Items: Royal Edition 2022-06-15
# 1       RPG                                    Land of Eem 2022-08-12
# 2    non-5E                                      The Weird 2022-10-08
# 3    non-5E       Coyote & Crow: Stories of the Free Lands 2022-10-13
# 4       RPG                                            ink 2022-11-01
# ..      ...                                            ...        ...
# 590  non-5E               Land of Eem - edición en español        NaT
# 591     RPG  Amboria: World Under Starlight - Last Chance!        NaT
# 592  non-5E                               Ultimate Toolbox        NaT
# 593  non-5E                  Unnatural Selections Volume 4        NaT
# 594  non-5E                      Draw Steel: Crack the Sun        NaT
#
#      Funding Level  Funding Goal Project Status  \
# 0           3601.0         500.0  Project Ended
# ...

# %%
backerkit['Project Status'] = backerkit['Project Status'].fillna('Ongoing')

# %%
backerkit['Project Status'].value_counts()
# Out:
# Project Status
# Project Ended    578
# Ongoing           13
# Canceled           4
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

status_counts = backerkit['Project Status'].value_counts()
percentages = status_counts / status_counts.sum() * 100

legend_labels = [
    f"{status}: {pct:.1f}%"
    for status, pct in zip(status_counts.index, percentages)
]

plt.figure(figsize=(8, 6))
plt.pie(
    status_counts,
    labels=None,          
    startangle=90,
    wedgeprops={'edgecolor': 'white'}
)

plt.legend(
    legend_labels,
    title="Project Status",
    loc="center left",
    bbox_to_anchor=(1, 0.5)
)

plt.title("Backerkit Project Status Distribution")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

currency_counts = backerkit['Currency'].value_counts().head(6)

plt.figure(figsize=(8, 5))
plt.bar(currency_counts.index, currency_counts.values)

plt.title('Top 6 Currencies by Number of BackerKit Projects')
plt.xlabel('Currency')
plt.ylabel('Number of Projects')
plt.xticks(rotation=45, ha='right')

for i, v in enumerate(currency_counts.values):
    plt.text(i, v, str(v), ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

# %%
backerkit['Real Funding USD'] = pd.to_numeric(backerkit['Real Funding USD'], errors='coerce')
backerkit['Ended Date'] = pd.to_datetime(backerkit['Ended Date'], errors='coerce')

bk_filtered = backerkit.dropna(subset=['Ended Date'])

top_currencies = (
    bk_filtered[bk_filtered['Currency'] != 'USD']
    .groupby('Currency')['Real Funding USD']
    .sum()
    .sort_values(ascending=False)
    .head(6)
    .index
)

bk_top = bk_filtered[bk_filtered['Currency'].isin(top_currencies)]

funding_over_time = bk_top.groupby(['Ended Date', 'Currency'])['Real Funding USD'].sum().unstack(fill_value=0)

plt.figure(figsize=(12, 6))
for currency in funding_over_time.columns:
    plt.plot(funding_over_time.index, funding_over_time[currency], marker='', linestyle='-', label=currency)

plt.title('Real Funding USD Over Time by Currency (Excluding USD)')
plt.xlabel('Ended Date')
plt.ylabel('Funding (USD)')
plt.legend(title='Currency', bbox_to_anchor=(1, 1))
plt.grid(True)

plt.gca().get_yaxis().set_major_formatter(mtick.StrMethodFormatter('${x:,.0f}'))

plt.tight_layout()
plt.show()

# %%
backerkit['Real Funding USD'] = pd.to_numeric(backerkit['Real Funding USD'], errors='coerce')
backerkit['Ended Date'] = pd.to_datetime(backerkit['Ended Date'], errors='coerce')

bk_usd = backerkit[(backerkit['Currency'] == 'USD') & (backerkit['Ended Date'].notna())]

funding_usd_over_time = bk_usd.groupby('Ended Date')['Real Funding USD'].sum()

plt.figure(figsize=(12, 6))
plt.plot(funding_usd_over_time.index, funding_usd_over_time.values, marker='', linestyle='-', color='blue', label='USD')

plt.title('Real Funding USD Over Time (USD Projects Only)')
plt.xlabel('Ended Date')
plt.ylabel('Funding (USD)')
plt.grid(True)
plt.legend()

plt.gca().get_yaxis().set_major_formatter(mtick.StrMethodFormatter('${x:,.0f}'))

plt.tight_layout()
plt.show()

# %%
gametable
# Out:
#                                    GameOnTabletop Link  \
# 0    https://www.gameontabletop.com/cf3291/la-foret...
# 1    https://www.gameontabletop.com/cf3971/les-miro...
# 2    https://www.gameontabletop.com/cf3991/chroniqu...
# 3    https://www.gameontabletop.com/cf4441/dream-as...
# 4    https://www.gameontabletop.com/cf2021/shiver-l...
# ..                                                 ...
# 511  https://www.gameontabletop.com/cf4251/guide-ul...
# 512  https://www.gameontabletop.com/cf5851/symbarou...
# 513  https://www.gameontabletop.com/cf5371/les-gard...
# 514  https://www.gameontabletop.com/cf5941/vaesen-m...
# 515  https://www.gameontabletop.com/cf5391/n-est-pa...
#
#                                      RPGGeek List Item    Type  \
# 0    https://rpggeek.com/geeklist/360124/gameontabl...     RPG
# 1    https://rpggeek.com/geeklist/360124/gameontabl...  non-5E
# 2    https://rpggeek.com/geeklist/360124/gameontabl...  non-5E
# ...
